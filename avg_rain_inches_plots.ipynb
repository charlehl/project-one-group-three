# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
rain = "Resources/avg_rain_inches.csv"
passengers_temp = "Resources/averages_temp_passengers.csv"

# %%
rain_df = pd.read_csv(rain)

rain_df
# Out:
#         Month  Cancun(avg.rain)  London(avg.rain)  Tokyo(avg.rain)  \
# 0     January              2.56              2.44             2.56
# 1    February              1.33              1.78             2.56
# 2       March              1.71              1.46             4.76
# 3       April              1.54              1.42             5.31
# 4         May              3.30              1.59             5.61
# 5        June              6.02              1.54             6.26
# 6        July              4.76              1.71             6.47
# 7      August              5.86              2.32             6.35
# 8   September              9.21              2.13             8.62
# 9     October              8.42              2.81             8.42
# 10   November              4.25              2.72             4.02
# 11   December              3.17              2.56             2.20
#
#     Toronto(avg.rain)  Mexico City(avg.rain)  Amsterdam(avg.rain)  \
# 0                3.31                   0.85                 2.81
# 1                2.22                   1.45                 2.45
# 2                2.32                   1.95                 2.07
# 3                3.19                   2.83                 1.77
# 4                3.42                   5.61                 2.20
# 5                3.54                   8.86                 2.60
# 6                3.54                   9.76                 3.30
# 7                3.17                   9.52                 3.78
# 8                3.31                   8.50                 3.43
# 9                3.42                   4.52                 3.54
# 10               3.07                   1.77                 3.54
# 11               2.93                   1.10                 3.42
#
#     Paris(avg.rain)  Punta Cana(avg.rain)  Vancouver(avg.rain)  \
# 0              1.95                  2.81                 8.67
# 1              1.78                  2.22                 5.23
# 2              1.83                  2.69                 6.35
# 3              2.01                  4.37                 4.37
# 4              2.56                  6.35                 3.17
# 5              2.36                  4.49                 2.60
# 6              2.69                  5.13                 1.46
# 7              2.44                  6.71                 1.83
# 8              2.13                  8.62                 2.72
# 9              2.32                  7.93                 6.59
# 10             2.13                  6.02                10.04
# 11             2.32                  3.17                 8.18
#
#     San Jose del Cabo(avg.rain)
# 0                          0.37
# 1                          0.33
# 2                          0.12
# 3                          0.00
# 4                          0.00
# 5                          0.12
# 6                          0.61
# 7                          1.95
# 8                          4.13
# 9                          1.59
# 10                         0.83
# 11                         0.49

# %%
passengers_temp_df = pd.read_csv(passengers_temp)
del passengers_temp_df["Unnamed: 0"]
passengers_temp_df
# Out:
#         Month  Amsterdam(avg)  Amsterdam(avg.Temp)  Cancun(avg)  \
# 0     January         91505.2                 38.1     309181.2
# 1    February         75592.2                 38.3     318929.4
# 2       March        107990.2                 43.0     394818.4
# 3       April        132992.4                 48.4     334011.8
# 4         May        159123.4                 55.2     326086.6
# 5        June        162264.2                 69.7     355326.0
# 6        July        147283.2                 63.7     372564.4
# 7      August        164825.4                 63.5     299043.0
# 8   September        155944.4                 58.5     183154.6
# 9     October        137153.8                 51.8     228564.6
# 10   November         99926.6                 44.8     278587.0
# 11   December        108589.2                 39.2     360814.8
#
#     Cancun(avg.Temp)  London(avg)  London(avg.Temp)  Mexico City(avg)  \
# 0               75.4     187661.4              44.2          128736.6
# 1               76.6     143290.0              44.2          107547.8
# 2               78.4     207920.6              47.8          121466.2
# 3               81.3     238232.0              53.6          116774.6
# 4               83.7     264697.6              58.6          123001.6
# 5               84.6     297033.6              64.9          141108.4
# 6               85.1     258365.4              67.3          155904.8
# 7               85.5     282617.6              66.9          144418.8
# 8               84.0     271376.8              63.1          114915.4
# 9               81.5     228461.0              56.3          132419.4
# 10              78.6     201949.4              50.0          139961.6
# 11              76.1     230053.6              44.6          173437.2
#
#     Mexico City(avg.Temp)  Paris(avg)         ...           Punta Cana(avg)  \
# 0                    58.3     83466.2         ...                   89834.6
# 1                    60.6     67376.4         ...                   99100.6
# 2                    64.6    105123.6         ...                  127465.8
# 3                    67.3    118943.2         ...                  112788.2
# 4                    68.0    145812.0         ...                  116602.8
# 5                    66.9    155217.4         ...                  146220.2
# 6                    64.8    140572.2         ...                  169855.6
# 7                    64.9    148760.6         ...                  116870.2
# 8                    64.4    140555.4         ...                   57878.2
# 9                    62.8    119060.0         ...                   66417.8
# 10                   61.3     91660.0         ...                   82939.6
# 11                   59.0    109214.4         ...                  108789.2
#
#     Punta Cana(avg.Temp)  San Jose del Cabo(avg)  San Jose del Cabo(avg.Temp)  \
# 0                   76.6                 91225.4                         66.0
# 1                   76.5                100929.2                         66.6
# 2                   77.0                133882.2                         68.2
# 3                   77.9                111107.0                         71.4
# 4                   79.5                103764.6                         75.2
# 5                   81.0                120193.8                         79.7
# 6                   81.5                122687.2                         83.3
# 7                   81.9                 93939.2                         84.0
# 8                   81.7                 53041.6                         82.8
# 9                   80.6                 79674.2                         79.2
# 10                  79.3                 96496.2                         73.9
# 11                  77.4                116683.4                         68.4
#
#     Tokyo(avg)  Tokyo(avg.Temp)  Toronto(avg)  Toronto(avg.Temp)  \
# 0     197732.2             41.4      116941.8               25.3
# 1     184500.2             42.3      110637.2               27.3
# 2     225549.8             47.7      137276.8               34.5
# 3     170352.6             57.0      132203.2               46.2
# 4     208884.4             64.8      146855.2               57.4
# 5     220942.8             70.5      143214.8               66.9
# 6     208070.8             77.0      148652.0               72.1
# 7     229965.6             79.5      158408.4               70.7
# 8     211589.8             73.0      143892.0               63.0
# 9     203541.8             63.5      143263.6               51.3
# 10    188810.4             53.8      125004.6               40.8
# 11    197594.4             45.7      116857.6               31.1
#
#     Vancouver(avg)  Vancouver(avg.Temp)
# 0          80604.6                 39.4
# 1          76467.4                 40.8
# 2          91708.4                 44.4
# 3          85081.2                 48.9
# 4         112560.2                 55.0
# 5         129728.8                 60.3
# 6         142155.0                 64.4
# 7         142382.8                 64.4
# 8         104048.4                 58.8
# 9          85545.2                 50.5
# 10         74079.8                 43.3
# 11         84189.0                 38.5
#
# [12 rows x 21 columns]

# %%
merged = pd.merge(passengers_temp_df,rain_df,on="Month",how="left")

# %%
## CANCUN ##

# set x_axis for passengers vs temperatures plot
# months will be variable to hold the months names
months = merged['Month']
# x_axis will be the range in the lenght of the column Month
x_axis = np.arange(len(months))
# define tick locations
tick_locations = [month for month in x_axis]

# average passengers vs average weather for SAN JOSE DEL CABO
# we will plot passengers and weather as y_axis 
# x_axis will be the months we defined above
can = merged['Cancun(avg)']
can_rain = merged['Cancun(avg.rain)']

# create subplot
fig, ax1 = plt.subplots()

# xlabel will be the Months and only needs to be set once for both
ax1.set_xlabel('Months')

# set variable to color of Passengers labels
color = 'tab:red'
# set the label paramenters for Passengers
ax1.set_ylabel('Average Passengers', color=color)
# plot the line for Passengers calling the color defined about
ax1.plot(x_axis, can, color=color)
# call the ticks and define paraments and color to match the line color
ax1.tick_params(axis='y', labelcolor=color)

# instantiate a second axes that shares the same x-axis
ax2 = ax1.twinx()  

# set variable to color of Weather labels
color = 'tab:blue'
# set the label paramenters for Weather
ax2.set_ylabel('Average Rain(inches)', color=color)  
# plot the line for Weather calling the color defined about
ax2.plot(x_axis, can_rain, color=color)
# call the ticks and define paraments and color to match the line color
ax2.tick_params(axis='y', labelcolor=color)

# place tick locations for x_axis
plt.xticks(tick_locations, months)
# format x_axis ticks
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45)
# add grid to plot
plt.grid(True)
# add title
plt.title('Cancun')
# otherwise the right y-label is slightly clipped
fig.tight_layout()
# save plot as png
#plt.savefig('Resources/san_jose_cabo_avg_pass_temp.png')
# display
plt.show()

# %%
# set x_axis for passengers vs temperatures plot
# months will be variable to hold the months names
months = merged['Month']
# x_axis will be the range in the lenght of the column Month
x_axis = np.arange(len(months))
# define tick locations
tick_locations = [month for month in x_axis]
new_scale =[scale*15 for scale in merged['Cancun(avg.rain)']]
# plot a line graph with markers to show passengers vs temperature
plt.scatter(x_axis, merged['Cancun(avg)'],color='blue',alpha=.5,s=new_scale, edgecolor="black")
# place ticks for x_axis
plt.xticks(tick_locations, months,rotation=45)
# add grip
plt.grid(True)
# add title and labels
plt.title('Cancun')
plt.xlabel('Average Rain(inches)')
plt.ylabel('Average Passengers')

note = "Note: Circle size correlates with average rain in inches"
plt.text(12,300000, note, rotation=0)
# otherwise the right y-label is slightly clipped
fig.tight_layout()  
# save plot into png
plt.savefig('Resources/cancun_rain.png')
# display plot
plt.show()

# %%
# set x_axis for passengers vs temperatures plot
# months will be variable to hold the months names
months = merged['Month']
# x_axis will be the range in the lenght of the column Month
x_axis = np.arange(len(months))
# define tick locations
tick_locations = [month for month in x_axis]
new_scale =[scale*15 for scale in merged['Punta Cana(avg.rain)']]
# plot a scatter graph with markers to show passengers vs temperature
plt.scatter(x_axis, merged['Punta Cana(avg)'],color='blue',alpha=.5,s=new_scale, edgecolor="black")
# place ticks for x_axis
plt.xticks(tick_locations, months,rotation=45)
# add grip
plt.grid(True)
# add title and labels
plt.title('Punta Cana')
plt.xlabel('Average Rain(inches)')
plt.ylabel('Average Passengers')

note = "Note: Circle size correlates with average rain in inches"
plt.text(12,120000, note, rotation=0)
# otherwise the right y-label is slightly clipped
fig.tight_layout()  
# save plot into png
plt.savefig('Resources/punta_cana_rain.png')
# display plot
plt.show()

# %%
# set x_axis for passengers vs temperatures plot
# months will be variable to hold the months names
months = merged['Month']
# x_axis will be the range in the lenght of the column Month
x_axis = np.arange(len(months))
# define tick locations
tick_locations = [month for month in x_axis]
new_scale =[scale*20 for scale in merged['San Jose del Cabo(avg.rain)']]
# plot a scatter graph with markers to show passengers vs temperature
plt.scatter(x_axis, merged['San Jose del Cabo(avg)'],color='blue',alpha=.5,s=new_scale, edgecolor="black")
# place ticks for x_axis
plt.xticks(tick_locations, months,rotation=45)
# add grip
plt.grid(True)
# add title and labels
plt.title('San Jose del Cabo')
plt.xlabel('Average Rain(inches)')
plt.ylabel('Average Passengers')

note = "Note: Circle size correlates with average rain in inches"
plt.text(12,90000, note, rotation=0)
# otherwise the right y-label is slightly clipped
fig.tight_layout()  
# save plot into png
plt.savefig('Resources/san_jose_cabo_rain.png')
# display plot
plt.show()
